# %%
import pandas as pd
import kagglehub

# %% [markdown]
# #### We need to access our data from Kaggle. We do this with the "kagglehub" package.

# %%
# Download latest version
path = kagglehub.dataset_download("rhuebner/human-resources-data-set")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\T1M\.cache\kagglehub\datasets\rhuebner\human-resources-data-set\versions\4

# %% [markdown]
# Now lets load our data in a pandas dataframe to have a look on it.

# %%
df = pd.read_csv(r"C:\Users\T1M\.cache\kagglehub\datasets\rhuebner\human-resources-data-set\versions\4\HRDataset_v14.csv")

df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# #### Lets get in touch with the general structure of the data set.

# %%
print("General Structure of our data")
print(" ")
print(" ")

print(df.shape)
print("---------------")
print(df.columns)
print("---------------")
print(df.describe(include = "all"))
print("---------------")
print(df.info())
# Out:
# General Structure of our data
#
#
# (311, 36)
# ---------------
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')
# ---------------
#               Employee_Name         EmpID   MarriedID  MaritalStatusID  \
# count                   311    311.000000  311.000000       311.000000
# unique                  311           NaN         NaN              NaN
# ...

# %%
df.to_csv(r'C:\Projekt_Ordner\HR_Analysis\Data\HR_Dataset.csv', index=False)
